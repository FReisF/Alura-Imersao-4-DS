# %% [markdown]
# <a href="https://colab.research.google.com/github/FReisF/Alura-Imersao-4-DS/blob/main/FRF_Imersao_dados_4_aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                    Rua                   Bairro     Cidade  \
# 2938                               NaN          Jardim Paulista  São Paulo
# 2432          Rua Vicente Biondo, 216   Vila Ester (Zona Norte)  São Paulo
# 4325                        Rua Anunze                  Boaçava  São Paulo
# 1787  Rua Marechal Renato Paquet, 463          Jardim Marajoara  São Paulo
# 5178                     Rua Itaperuna                 Pacaembu  São Paulo
# 7625                   Rua Sanharó, 0            Jardim Guedala  São Paulo
# 9068             Avenida das Magnólias            Cidade Jardim  São Paulo
# 3890                               NaN          Jardim Paulista  São Paulo
# 6777                               NaN        Brooklin Paulista  São Paulo
# 9447                Rua Vieira de Melo   Jardim Virginia Bianca  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas          Valor
# 2938       800        5          7      6   R$ 9.580.000
# 2432       226        3          1      4     R$ 670.000
# 4325       410        3          5      4   R$ 4.300.000
# 1787       197        4          4      4   R$ 1.400.000
# 5178      1000        4          9      4  R$ 11.990.000
# 7625       286        2          4      4   R$ 1.700.000
# 9068       805        4          6      8  R$ 10.000.000
# 3890       500        4          4      4   R$ 5.950.000
# 6777       180        3          3      2   R$ 1.200.000
# 9447       100        3          1      1     R$ 460.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# 120         3          5      2  R$ 2.450.000
# 155         3          4      2  R$ 1.490.000
# 160         4          5      3  R$ 2.200.000
# 334         6          4     10  R$ 1.700.000
# ...       ...        ...    ...           ...
# 9645        3          5      5  R$ 1.650.000
# 9701        3          2      4  R$ 1.650.000
# 9737        3          2      4  R$ 1.650.000
# 9807        3          1      6  R$ 1.500.000
# 9852        3          3      4  R$ 1.600.000
#
# [184 rows x 8 columns]

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                Rua             Bairro     Cidade  Metragem  \
# 1484  Rua Gregório Paes de Almeida      Vila Madalena  São Paulo       400
# 4425             Rua Sampaio Vidal  Jardim Paulistano  São Paulo       200
# 3489          Rua Dom Miguel Costa    Vila Gumercindo  São Paulo       140
# 6870            Rua Joaquim Nabuco  Brooklin Paulista  São Paulo       647
# 1775                 Rua Nova York  Brooklin Paulista  São Paulo       350
# 4087                    Rua Iraúna  Jardim Novo Mundo  São Paulo       220
# 38      Rua Zacarias de Gois, 431     Parque Colonial  São Paulo       138
# 5615                           NaN        Vila Carrão  São Paulo       355
# 3112          Praça Santos Coimbra            Morumbi  São Paulo       565
# 2920    Rua Comendador Elias Jafet      Jardim Leonor  São Paulo       493
#
#       Quartos  Banheiros  Vagas         Valor
# 1484        3          5      3  R$ 4.400.000
# 4425        3          4      6  R$ 5.500.000
# 3489        3          1      3    R$ 870.000
# 6870        5          2      5  R$ 3.400.000
# 1775        3          3      5  R$ 2.500.000
# 4087        4          3      4  R$ 2.800.000
# 38          3          1      3  R$ 1.060.000
# 5615        3          3      8  R$ 1.200.000
# 3112        3          4      8  R$ 3.500.000
# 2920        4          4      6  R$ 2.900.000

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 10002         None
# 10003         None
# 10004         None
# 10005         None
# 10007         None
#
# [9156 rows x 11 columns]

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas["Valor_anuncio_float"].plot.hist(bins = 50)

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# #Desafio Aula 2
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusão
# - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %%
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float
# 0           7000000.00
# 1           3700000.00
# 2            380000.00
# 3            685000.00
# 4            540000.00

# %%
dados_vendas["Valor_m2"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"]
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float  Valor_m2
# 0           7000000.00   7000.00
# 1           3700000.00   7459.68
# 2            380000.00   3040.00
# 3            685000.00   2209.68
# 4            540000.00   5400.00

# %%
#Media é um valor relativo. Dependendo da distribuicao dos dados a conclusao pode mudar
dados_vendas.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor_m2
# Bairro
# Aclimação           7656.17
# Alto da Boa Vista   5849.57
# Alto da Lapa        7606.73
# Alto da Mooca       5691.74
# Alto de Pinheiros  11269.98
# ...                     ...
# Vila Água Funda     4467.13
# Água Branca         7269.11
# Água Fria           5841.10
# Água Funda          3876.86
# Água Rasa           4509.61
#
# [697 rows x 6 columns]

# %%
dados_bairro = dados_vendas.groupby("Bairro").sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2
# Bairro
# Aclimação          604837.39
# Alto da Boa Vista   46796.55
# Alto da Lapa       608538.25
# Alto da Mooca      113834.80
# Alto de Pinheiros 4158622.61
# ...                      ...
# Vila Água Funda     22335.64
# Água Branca         87229.37
# Água Fria           70093.25
# Água Funda           7753.73
# Água Rasa           27057.65
#
# [697 rows x 6 columns]

# %%
dados_bairro["Valor_m2_bairro"] = dados_bairro["Valor_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2  Valor_m2_bairro
# Bairro
# Aclimação          604837.39          7162.69
# Alto da Boa Vista   46796.55          5708.74
# Alto da Lapa       608538.25          6961.30
# Alto da Mooca      113834.80          4385.00
# Alto de Pinheiros 4158622.61         11126.34
# ...                      ...              ...
# Vila Água Funda     22335.64          4283.84
# Água Branca         87229.37          7065.77
# Água Fria           70093.25          5604.53
# Água Funda           7753.73          3920.86
# Água Rasa           27057.65          3846.91
#
# [697 rows x 7 columns]

# %%
dados_vendas.groupby("Bairro").mean().loc["Vila Mariana"]
# Out:
# Metragem                  231.24
# Quartos                     3.39
# Banheiros                   3.24
# Vagas                       2.95
# Valor_anuncio_float   1771159.76
# Valor_m2                 7913.15
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc["Vila Mariana"]
# Out:
# Metragem                  39079.00
# Quartos                     573.00
# Banheiros                   547.00
# Vagas                       499.00
# Valor_anuncio_float   299326000.00
# Valor_m2                1337323.16
# Valor_m2_bairro            7659.51
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro["Valor_m2_bairro"]["Vila Mariana"]
# Out:
# 7659.510222881855

# %%
top_bairros = dados_vendas["Bairro"].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 0           139292801.00  604837.39          7162.69
# 1            19130000.00   46796.55          5708.74
# 2           166653500.00  608538.25          6961.30
# 3            23683400.00  113834.80          4385.00
# 4          1764815915.00 4158622.61         11126.34
# ..                   ...        ...              ...
# 692           3260000.00   22335.64          4283.84
# 693          14718000.00   87229.37          7065.77
# 694          11125000.00   70093.25          5604.53
# 695           1090000.00    7753.73          3920.86
# 696           4297000.00   27057.65          3846.91
#
# [697 rows x 8 columns]

# %%
dados_bairro.query("Bairro in @top_bairros")
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# 168        1801165587.00 2833882.79          1852.65
# 187         646326369.00 1115858.80          6653.49
# 227        2136081000.00 4279262.19         16395.70
# 338         867956500.00 1753672.28          8654.90
# 396         374907000.00 1186380.95          6327.54
# 564         583253030.00 1792770.40          8803.82

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro.query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros"), x="Bairro", y="Valor_anuncio_float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#Remove outlier com metragem acima de 30 000 m2
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio  Valor_anuncio_float  Valor_m2
# 0             None           7000000.00   7000.00
# 1             None           3700000.00   7459.68
# 2             None            380000.00   3040.00
# 3             None            685000.00   2209.68
# 4             None            540000.00   5400.00
# ...            ...                  ...       ...
# 10002         None           1500000.00   5617.98
# 10003         None            665000.00   7000.00
# 10004         None           2300000.00   3801.65
# 10005         None           1050000.00   5121.95
# 10007         None            270000.00   2213.11
#
# [9156 rows x 13 columns]

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
pd.read_csv(ibge_url)
# Out:
#                                                                                                                                                Cod_setor;Cod_Grandes Regi�es;Nome_Grande_Regiao;Cod_UF;Nome_da_UF ;Cod_meso;Nome_da_meso;Cod_micro;Nome_da_micro;Cod_RM;Nome_da_RM;Cod_municipio;Nome_do_municipio;Cod_distrito;Nome_do_distrito;Cod_subdistrito;Nome_do_subdistrito;Cod_bairro;Nome_do_bairro;Situacao_setor;Tipo_setor;V001;V002;V003;V004;V005;V006;V007;V008;V009;V010;V011;V012;
# 355030801000001;3;"Regi�o Sudeste";35;"S�o Paul... 01;2 32;2091 32;8532451           78;2164 55;8673276 78;1227 41;4285771 99;1713 75;5152087                                              86.00
# 355030801000002;3;"Regi�o Sudeste";35;"S�o Paul... 98;2 09;1650 09;3983441           31;1717 44;4030519 99;1045 78;2572133 32;1468 08;2991546                                              94.00
# 355030801000003;3;"Regi�o Sudeste";35;"S�o Paul... 31;3 08;1280 43;5474593           06;2349 53;7553913 02;902  97;2735492 52;1786 79;3837674                                              74.00
# 355030801000004;3;"Regi�o Sudeste";35;"S�o Paul... 16;2 26;1119 59;3572955           1;1859  13;4567289 5;869   09;2122409 02;1567 41;2735383                                              24.00
# 355030801000005;3;"Regi�o Sudeste";35;"S�o Paul... 14;2 35;1416 9;2240207            58;1581 66;2240109 39;917  71;1570047 75;1356 35;1725877                                              85.00
# ...                                                                                                                                                                                          ...
# 355030896000243;3;"Regi�o Sudeste";35;"S�o Paul... 5;2  61;772  09;168751            1;814   52;143188  21;467  46;191332  48;699  95;123399                                                8.00
# 355030896000244;3;"Regi�o Sudeste";35;"S�o Paul... 87;2 49;692  5;239941             27;812  93;182516  2;439   33;194034  99;702  1;124952                                                38.00
# 355030896000245;3;"Regi�o Sudeste";35;"S�o Paul... 9;2  54;630  06;329705            22;843  31;260395  9;347   6;228162   66;767  5;181129                                                99.00
# 355030896000246;3;"Regi�o Sudeste";35;"S�o Paul... 29;4 21;597  37;349101;908;244391 67;397  76;436942  16;854  2;550319   43      NaN                                                       NaN
# 355030896000247;3;"Regi�o Sudeste";35;"S�o Paul... 77;3 28;630  13;183904            29;790  88;102860  11;431  82;186963  45;728  7;98771                                                 74.00
#
# [18363 rows x 1 columns]

# %% [markdown]
# ##Desafio Aula 3
#
# - Tentar vincular dados do IBGE com os dados de imóveis.
# - Tratar os outliers e comparar com os resultados.
# - Agrupar por mais de uma categoria e realizar as análises.
# - Organize o colab para deixar com cara de projeto.

# %% [markdown]
# ![sp.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Tentar vincular dados do IBGE com os dados de imóveis.**

# %%
ibge = pd.read_csv(ibge_url,sep=';',decimal = ',',encoding = "utf8")
ibge = ibge.replace('�','a', regex=True)

# %%
dados["Bairro"] = dados['Bairro'].str.upper()
dados_vendas["Bairro"] = dados_vendas['Bairro'].str.upper()
dados_bairro["Bairro"] = dados_bairro['Bairro'].str.upper()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
arruma_acc = {'aGUA RASA':'ÁGUA RASA', 'BELaM':'BELÉM',
       'BRaS':"BRÁS", 'BRASILaNDIA':"BRASILÃNDIA", 'BUTANTa':"BUTANTÃ",
       'CAPaO REDONDO':"CAPÃO REDONDO", 'CARRaO':"CARRÃO", 'CONSOLAaaO':"CONSOLAÇÃO", 'FREGUESIA DO a':"FREGUESIA DO Ó", 'GRAJAa':"GRAJAÚ", 'JAaANa':"JAÇANÃ",
       'JAGUARa':"JAGUARÁ", 'JARAGUa':"JARAGUÁ", 'JARDIM aNGELA':"JARDIM ÂNGELA", 'JARDIM SaO LUaS':"JARDIM SÃO LUÍS", 'JOSa BONIFaCIO':"JOSÉ BONIFÁCIO", 'LIMaO':"LIMÃO",
       'REPaBLICA':"REPÚBLICA", 'SACOMa':"SACOMÃ",
       'SANTA CECaLIA':"SANTA CECÍLIA", 'SaO':"SÃO","SÉo":"SÃO", 'SAaDE':"SAÚDE",
       'Sa':"SÉ", 'TATUAPa':"TATUAPÉ", 'TREMEMBa':"TREMEMBÉ",
       'VILA CURUaa':"VILA CURUÇÁ", 'VILA JACUa':"VILA JACUÍ", 'VILA SaNIA':"VILA SÔNIA"}

# %%
ibge = ibge.replace(arruma_acc, regex=True)
ibge.rename(columns = {'Nome_do_subdistrito':'Bairro'},inplace = True)

# %%
dados.merge(ibge, on = 'Bairro', how = 'left')
# Out:
#                                    Rua              Bairro     Cidade  \
# 0                Avenida Itacira, 255    PLANALTO PAULISTA  São Paulo
# 1       Rua Aurelia Perez Alvarez, 42   JARDIM DOS ESTADOS  São Paulo
# 2                      Rua Alba Valdez     JARDIM REIMBERG  São Paulo
# 3                                  NaN      JARDIM MORUMBI  São Paulo
# 4             Rua Tobias Barreto, 195                MOOCA  São Paulo
# ...                                ...                 ...        ...
# 370943                      Rua Tapuçu          VILA SOFIA  São Paulo
# 370944                   Rua Guararema     BOSQUE DA SAÚDE  São Paulo
# 370945               Rua Estero Belaco       VILA DA SAÚDE  São Paulo
# 370946         Rua Manuel Onha, , 514        VILA ORATÓRIO  São Paulo
# 370947      Rua Barão de Tramandaí, 0          VILA ALPINA  São Paulo
#
#         Metragem  Quartos  Banheiros  Vagas  \
# 0           1000        4          8      6
# 1            496        4          4      4
# 2            125        4          3      2
# 3            310        3          2      4
# 4            100        3          2      2
# ...          ...      ...        ...    ...
# 370943        95        2          2      2
# 370944       605        8          7      5
# 370945       205        3          3      6
# 370946       185        3          2      2
# 370947       122        3          2      2
#
#                                        Valor Moeda Valor_anuncio  ... V004  \
# 0                               R$ 7.000.000    R$     7.000.000  ...  NaN
# 1                               R$ 3.700.000    R$     3.700.000  ...  NaN
# 2                                 R$ 380.000    R$       380.000  ...  NaN
# 3                                 R$ 685.000    R$       685.000  ...  NaN
# 4                                 R$ 540.000    R$       540.000  ... 2.24
# ...                                      ...   ...           ...  ...  ...
# 370943                            R$ 665.000    R$       665.000  ...  NaN
# 370944                          R$ 2.300.000    R$     2.300.000  ...  NaN
# 370945                          R$ 1.050.000    R$     1.050.000  ...  NaN
# 370946  R$ 2.200\n                      /Mês    R$         2.200  ...  NaN
# 370947                            R$ 270.000    R$       270.000  ...  NaN
#
#           V005       V006    V007       V008    V009       V010    V011  \
# 0          NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 1          NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 2          NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 3          NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 4      2197.44 6690242.53 2343.94 6793646.01 1490.00 4602284.67 1893.07
# ...        ...        ...     ...        ...     ...        ...     ...
# 370943     NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 370944     NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 370945     NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 370946     NaN        NaN     NaN        NaN     NaN        NaN     NaN
# 370947     NaN        NaN     NaN        NaN     NaN        NaN     NaN
#
#              V012 Unnamed: 33
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4      5085711.93         NaN
# ...           ...         ...
# 370943        NaN         NaN
# 370944        NaN         NaN
# 370945        NaN         NaN
# 370946        NaN         NaN
# 370947        NaN         NaN
#
# [370948 rows x 44 columns]

# %%
dados_vendas.merge(ibge, on = 'Bairro', how = 'left')
# Out:
#                                    Rua              Bairro     Cidade  \
# 0                Avenida Itacira, 255    PLANALTO PAULISTA  São Paulo
# 1       Rua Aurelia Perez Alvarez, 42   JARDIM DOS ESTADOS  São Paulo
# 2                      Rua Alba Valdez     JARDIM REIMBERG  São Paulo
# 3                                  NaN      JARDIM MORUMBI  São Paulo
# 4             Rua Tobias Barreto, 195                MOOCA  São Paulo
# ...                                ...                 ...        ...
# 338314                   Avenida Odila   PLANALTO PAULISTA  São Paulo
# 338315                      Rua Tapuçu          VILA SOFIA  São Paulo
# 338316                   Rua Guararema     BOSQUE DA SAÚDE  São Paulo
# 338317               Rua Estero Belaco       VILA DA SAÚDE  São Paulo
# 338318      Rua Barão de Tramandaí, 0          VILA ALPINA  São Paulo
#
#         Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0           1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1            496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2            125        4          3      2    R$ 380.000    R$       380.000
# 3            310        3          2      4    R$ 685.000    R$       685.000
# 4            100        3          2      2    R$ 540.000    R$       540.000
# ...          ...      ...        ...    ...           ...   ...           ...
# 338314       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 338315        95        2          2      2    R$ 665.000    R$       665.000
# 338316       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 338317       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 338318       122        3          2      2    R$ 270.000    R$       270.000
#
#         ... V004    V005       V006    V007       V008    V009       V010  \
# 0       ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 1       ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 2       ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 3       ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 4       ... 2.24 2197.44 6690242.53 2343.94 6793646.01 1490.00 4602284.67
# ...     ...  ...     ...        ...     ...        ...     ...        ...
# 338314  ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 338315  ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 338316  ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 338317  ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 338318  ...  NaN     NaN        NaN     NaN        NaN     NaN        NaN
#
#           V011       V012 Unnamed: 33
# 0          NaN        NaN         NaN
# 1          NaN        NaN         NaN
# 2          NaN        NaN         NaN
# 3          NaN        NaN         NaN
# 4      1893.07 5085711.93         NaN
# ...        ...        ...         ...
# 338314     NaN        NaN         NaN
# 338315     NaN        NaN         NaN
# 338316     NaN        NaN         NaN
# 338317     NaN        NaN         NaN
# 338318     NaN        NaN         NaN
#
# [338319 rows x 46 columns]

# %%
dados_bairro.merge(ibge, on = 'Bairro', how = 'left')
# Out:
#                   Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0              ACLIMAÇÃO     19447      258        240    230
# 1      ALTO DA BOA VISTA      3351       33         41     37
# 2           ALTO DA LAPA     23940      252        308    320
# 3          ALTO DA MOOCA      5401       66         52     73
# 4      ALTO DE PINHEIROS    158616     1453       1782   1827
# ...                  ...       ...      ...        ...    ...
# 10837          ÁGUA RASA      1117       16         12     22
# 10838          ÁGUA RASA      1117       16         12     22
# 10839          ÁGUA RASA      1117       16         12     22
# 10840          ÁGUA RASA      1117       16         12     22
# 10841          ÁGUA RASA      1117       16         12     22
#
#        Valor_anuncio_float   Valor_m2  Valor_m2_bairro          Cod_setor  \
# 0             139292801.00  604837.39          7162.69                NaN
# 1              19130000.00   46796.55          5708.74                NaN
# 2             166653500.00  608538.25          6961.30                NaN
# 3              23683400.00  113834.80          4385.00                NaN
# 4            1764815915.00 4158622.61         11126.34 355030802000001.00
# ...                    ...        ...              ...                ...
# 10837           4297000.00   27057.65          3846.91 355030801000126.00
# 10838           4297000.00   27057.65          3846.91 355030801000127.00
# 10839           4297000.00   27057.65          3846.91 355030801000128.00
# 10840           4297000.00   27057.65          3846.91 355030801000129.00
# 10841           4297000.00   27057.65          3846.91 355030801000130.00
#
#        Cod_Grandes Regi�es  ... V004     V005          V006     V007  \
# 0                      NaN  ...  NaN      NaN           NaN      NaN
# 1                      NaN  ...  NaN      NaN           NaN      NaN
# 2                      NaN  ...  NaN      NaN           NaN      NaN
# 3                      NaN  ...  NaN      NaN           NaN      NaN
# 4                     3.00  ... 2.44 12262.45  159870161.44 12501.32
# ...                    ...  ...  ...      ...           ...      ...
# 10837                 3.00  ... 1.44  2225.18   22464342.87  5025.58
# 10838                 3.00  ... 2.52  2128.95    7805924.83  2685.02
# 10839                 3.00  ... 1.29  8000.86 2248223528.14 11295.34
# 10840                 3.00  ... 1.45  4332.11   12091773.68  4377.72
# 10841                 3.00  ... 1.46  2789.46    4431535.78  2936.27
#
#                V008    V009         V010    V011          V012  Unnamed: 33
# 0               NaN     NaN          NaN     NaN           NaN          NaN
# 1               NaN     NaN          NaN     NaN           NaN          NaN
# 2               NaN     NaN          NaN     NaN           NaN          NaN
# 3               NaN     NaN          NaN     NaN           NaN          NaN
# 4      159999050.55 5832.73 100963455.68 7999.64  121194261.04          NaN
# ...             ...     ...          ...     ...           ...          ...
# 10837   36759423.46 1425.05  12571352.76 4220.97   25483670.53          NaN
# 10838    8355829.90 1377.28   5388156.23 2245.16    6839880.08          NaN
# 10839 3144280336.75 4891.00 842812804.98 7734.20 1312387298.67          NaN
# 10840   12018656.74 2655.98   9296824.06 3419.02    9359216.76          NaN
# 10841    4232642.54 1894.51   3924424.33 2461.33    3702849.25          NaN
#
# [10842 rows x 41 columns]

# %% [markdown]
# **Tratar os outliers e comparar com os resultados.**

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  Valor_m2
# count   9156.00  9156.00    9156.00 9156.00              9156.00   9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96   8004.07
# std     7856.42     1.05       1.97    2.60           3944208.19   5291.32
# min       10.00     1.00       1.00    1.00             13000.00      9.33
# 25%      168.00     3.00       2.00    2.00            890000.00   4750.00
# 50%      276.00     3.00       4.00    4.00           1800000.00   6500.00
# 75%      450.00     4.00       5.00    5.00           3500000.00   9453.78
# max   750000.00    16.00      40.00   50.00          65000000.00  80000.00

# %%
dados_vendas_norm = dados_vendas[(dados_vendas['Metragem'] < 750000)&(dados_vendas['Banheiros'] < 40)&(dados_vendas['Vagas'] < 50)].copy()
dados_vendas_norm
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    PLANALTO PAULISTA  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   JARDIM DOS ESTADOS  São Paulo
# 2                     Rua Alba Valdez     JARDIM REIMBERG  São Paulo
# 3                                 NaN      JARDIM MORUMBI  São Paulo
# 4            Rua Tobias Barreto, 195                MOOCA  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   PLANALTO PAULISTA  São Paulo
# 10003                      Rua Tapuçu          VILA SOFIA  São Paulo
# 10004                   Rua Guararema     BOSQUE DA SAÚDE  São Paulo
# 10005               Rua Estero Belaco       VILA DA SAÚDE  São Paulo
# 10007      Rua Barão de Tramandaí, 0          VILA ALPINA  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio  Valor_anuncio_float  Valor_m2
# 0             None           7000000.00   7000.00
# 1             None           3700000.00   7459.68
# 2             None            380000.00   3040.00
# 3             None            685000.00   2209.68
# 4             None            540000.00   5400.00
# ...            ...                  ...       ...
# 10002         None           1500000.00   5617.98
# 10003         None            665000.00   7000.00
# 10004         None           2300000.00   3801.65
# 10005         None           1050000.00   5121.95
# 10007         None            270000.00   2213.11
#
# [9151 rows x 13 columns]

# %%
columns = ["Metragem","Quartos","Banheiros",	"Vagas","Valor_anuncio_float","Valor_m2"]
plt.figure(figsize=(10, 8))
top_bairros_upp = top_bairros.str.upper()
for column in columns:
  plt.figure(figsize=(10, 8))
  ax = sns.boxplot(data = dados_vendas_norm.query("Bairro in @top_bairros_upp"), x="Bairro", y=column)
  ax.tick_params(axis='x', rotation=45)
  plt.show()

# %% [markdown]
# Ao eliminar os valores maximos que pareciam ser outliers quase todos os parametros numericos se tornaram mais uniformes. A maior diferenca pode ser observada no numero de banheiros

# %%
top_bairros.str.upper()
# Out:
# Index(['ALTO DE PINHEIROS', 'JARDIM GUEDALA', 'JARDIM PAULISTA',
#        'BROOKLIN PAULISTA', 'JARDIM EUROPA', 'PACAEMBU', 'VILA MADALENA',
#        'CIDADE JARDIM', 'PLANALTO PAULISTA', 'JARDIM LEONOR'],
#       dtype='object')

# %% [markdown]
# **Agrupar por mais de uma categoria e realizar as análises.**

# %%
dados_vendas.groupby(['Bairro',"Rua"]).median().describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  Valor_m2
# count   3052.00  3052.00    3052.00 3052.00              3052.00   3052.00
# mean     306.10     3.32       3.46    3.56           2326696.33   7133.45
# std      700.76     1.03       1.73    2.31           3369043.61   4731.52
# min       10.00     1.00       1.00    1.00            130000.00     78.38
# 25%      150.00     3.00       2.00    2.00            745000.00   4347.03
# 50%      230.00     3.00       3.00    3.00           1300000.00   5948.11
# 75%      372.12     4.00       5.00    4.00           2600000.00   8379.67
# max    37000.00    16.00      14.00   38.00          65000000.00  80000.00

# %% [markdown]
# Agrupando por Bairro e Rua e aggregando os valores pela mediana ja que esses sao os dados com os outliers e possivel perceber que esses outliers nos valores maximos desaparecem.
